# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')
import hvplot.pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13796\3367091987.py in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import panel as pn
#       4 pn.extension('tabulator')
#       5 import hvplot.pandas
#
# ModuleNotFoundError: No module named 'panel'

# %%
if 'data' not in pn.state.cache.keys():

    df = pd.read_csv('StudentsPerformance.csv')

    pn.state.cache['data'] = df.copy()

else: 

    df = pn.state.cache['data']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23392\284448915.py in <module>
# ----> 1 if 'data' not in pn.state.cache.keys():
#       2
#       3     df = pd.read_csv('StudentsPerformance.csv')
#       4
#       5     pn.state.cache['data'] = df.copy()
#
# NameError: name 'pn' is not defined

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]
